# %%
import math


class Tracker:
    def __init__(self):
        # Store the center positions of the objects
        self.center_points = {}
        # Keep the count of the IDs
        self.id_count = 0


    def update(self, objects_rect):
        # Objects boxes and ids
        objects_bbs_ids = []

        # Get center point of new object
        for rect in objects_rect:
            x, y, w, h = rect
            cx = (x + x + w) // 2
            cy = (y + y + h) // 2

            # Find out if that object was detected already
            same_object_detected = False
            for id, pt in self.center_points.items():
                dist = math.hypot(cx - pt[0], cy - pt[1])

                if dist < 35:
                    self.center_points[id] = (cx, cy)
#                    print(self.center_points)
                    objects_bbs_ids.append([x, y, w, h, id])
                    same_object_detected = True
                    break

            # New object is detected we assign the ID to that object
            if same_object_detected is False:
                self.center_points[self.id_count] = (cx, cy)
                objects_bbs_ids.append([x, y, w, h, self.id_count])
                self.id_count += 1

        # Clean the dictionary by center points to remove IDS not used anymore
        new_center_points = {}
        for obj_bb_id in objects_bbs_ids:
            _, _, _, _, object_id = obj_bb_id
            center = self.center_points[object_id]
            new_center_points[object_id] = center

        # Update dictionary with IDs not used removed
        self.center_points = new_center_points.copy()
        return objects_bbs_ids

# %%
import cv2
import pandas as pd
from ultralytics import YOLO
import os
import time
from google.colab.patches import cv2_imshow
from pydub import AudioSegment
from pydub.generators import Sine
from moviepy.editor import VideoFileClip, concatenate_audioclips, AudioFileClip, CompositeAudioClip

# %%
model=YOLO('yolov8s.pt')


class_list = ['person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus', 'train', 'truck', 'boat', 'traffic light', 'fire hydrant',
              'stop sign', 'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear', 'zebra',
              'giraffe', 'backpack', 'umbrella', 'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball', 'kite',
              'baseball bat', 'baseball glove', 'skateboard', 'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup', 'fork',
              'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut',
              'cake', 'chair', 'couch', 'potted plant', 'bed', 'dining table', 'toilet', 'tv', 'laptop', 'mouse', 'remote', 'keyboard',
              'cell phone', 'microwave', 'oven','toaster', 'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors', 'teddy bear',
              'hair drier', 'toothbrush']


tracker=Tracker()

cap=cv2.VideoCapture('highway.mp4')

down = {}
up = {}
counter_down = []
counter_up = []
tickets = {}
count = 0
beep_timestamps = []

red_line_y = 198
blue_line_y = 268
offset = 6

# Create a folder to save frames
if not os.path.exists('detected_frames'):
    os.makedirs('detected_frames')

fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter('output_no_audio.avi', fourcc, 20.0, (1020, 500))


# Generate a beep sound (0.1-second duration at 1000 Hz)
beep = Sine(1000).to_audio_segment(duration=100)
beep.export("beep.wav", format="wav")

fps = cap.get(cv2.CAP_PROP_FPS)  # Get frames per second


while True:
    ret, frame = cap.read()
    if not ret:
        break
    count += 1
    frame = cv2.resize(frame, (1020, 500))

    results = model.predict(frame)
    d = results[0].boxes.data
    d = d.detach().cpu().numpy()
    px = pd.DataFrame(d).astype("float")
    list = []

    for index, row in px.iterrows():
        x1 = int(row[0])
        y1 = int(row[1])
        x2 = int(row[2])
        y2 = int(row[3])
        d = int(row[5])
        c = class_list[d]
        if 'car' in c or 'truck' in c or 'bus' in c:
            list.append([x1, y1, x2, y2])
    bbox_id = tracker.update(list)

    yellow_color = (0, 255, 255)  # Yellow color for background
    red_color = (0, 0, 255)  # Red color for lines
    blue_color = (255, 0, 0)  # Blue color for lines

    for bbox in bbox_id:
        x3, y3, x4, y4, id = bbox
        cx = int(x3 + x4) // 2
        cy = int(y3 + y4) // 2

        if red_line_y<(cy+offset) and red_line_y > (cy-offset):
           down[id]=time.time()   # current time when vehichle touch the first line
        if id in down:

           if blue_line_y<(cy+offset) and blue_line_y > (cy-offset):
             elapsed_time=time.time() - down[id]  # current time when vehicle touch the second line. Also we a re minusing the previous time ( current time of line 1)
             if counter_down.count(id)==0:
                counter_down.append(id)
                distance = 10 # meters  (Distance between the 2 lines is 10 meters )
                a_speed_ms = distance / elapsed_time
                a_speed_kh = a_speed_ms * 36  # this will give kilometers per hour for each vehicle. This is the condition for going downside
                color = red_color if a_speed_kh > 40 else blue_color
                if a_speed_kh > 40:
                  tickets[id] = [time.time(), 'South', a_speed_kh]
                  beep_timestamps.append(count / fps)  # Record beep timestamp

                cv2.circle(frame,(cx,cy),4,(0,0,255),-1)
                cv2.rectangle(frame, (x3, y3), (x4, y4), color, 2)  # Draw bounding box
                cv2.putText(frame,str(id),(x3,y3),cv2.FONT_HERSHEY_COMPLEX,0.6,(255,255,255),1)
                cv2.putText(frame,str(int(a_speed_kh))+'Km/h',(x4,y4 ),cv2.FONT_HERSHEY_COMPLEX,0.8,(0,255,255),2)


        #####going UP blue line#####
        if blue_line_y<(cy+offset) and blue_line_y > (cy-offset):
           up[id]=time.time()
        if id in up:

           if red_line_y<(cy+offset) and red_line_y > (cy-offset):
             elapsed1_time=time.time() - up[id]
             # formula of speed= distance/time
             if counter_up.count(id)==0:
                counter_up.append(id)
                distance1 = 10 # meters  (Distance between the 2 lines is 10 meters )
                a_speed_ms1 = distance1 / elapsed1_time
                a_speed_kh1 = a_speed_ms1 * 36
                if a_speed_kh1 > 40:
                  tickets[id] = [time.time(), 'North', a_speed_kh]
                  beep_timestamps.append(count / fps)  # Record beep timestamp

                color = red_color if a_speed_kh1 > 40 else blue_color
                cv2.circle(frame,(cx,cy),4,(0,0,255),-1)
                cv2.rectangle(frame, (x3, y3), (x4, y4), color, 2)  # Draw bounding box
                cv2.putText(frame,str(id),(x3,y3),cv2.FONT_HERSHEY_COMPLEX,0.6,(255,255,255),1)
                cv2.putText(frame,str(int(a_speed_kh1))+'Km/h',(x4,y4),cv2.FONT_HERSHEY_COMPLEX,0.8,(0,255,255),2)




    text_color = (0, 0, 0)


    cv2.rectangle(frame, (0, 0), (250, 90), yellow_color, -1)

    cv2.line(frame, (172, 198), (774, 198), yellow_color, 2)
    cv2.putText(frame, ('north Line'), (172, 198), cv2.FONT_HERSHEY_SIMPLEX, 0.5, text_color, 1, cv2.LINE_AA)

    cv2.line(frame, (8, 268), (927, 268), yellow_color, 2)
    cv2.putText(frame, ('south Line'), (8, 268), cv2.FONT_HERSHEY_SIMPLEX, 0.5, text_color, 1, cv2.LINE_AA)

    cv2.putText(frame, ('Going South - ' + str(len(counter_down))), (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.5, text_color, 1, cv2.LINE_AA)
    cv2.putText(frame, ('Going North - ' + str(len(counter_up))), (10, 60), cv2.FONT_HERSHEY_SIMPLEX, 0.5, text_color, 1, cv2.LINE_AA)

    # Save frame
    frame_filename = f'detected_frames/frame_{count}.jpg'
    cv2.imwrite(frame_filename, frame)

    out.write(frame)

    if cv2.waitKey(1) & 0xFF == 27:
    #if cv2.waitKey(0) & 0xFF == 27:
        break

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8s.pt to 'yolov8s.pt'...
# 100%|██████████| 21.5M/21.5M [00:00<00:00, 131MB/s]
# 0: 320x640 8 cars, 2 trucks, 1290.2ms
# Speed: 5.9ms preprocess, 1290.2ms inference, 34.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 545.5ms
# Speed: 3.3ms preprocess, 545.5ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 2 trucks, 482.3ms
# Speed: 3.3ms preprocess, 482.3ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 2 trucks, 322.4ms
# Speed: 3.0ms preprocess, 322.4ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 353.4ms
# Speed: 3.3ms preprocess, 353.4ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 506.1ms
# Speed: 3.8ms preprocess, 506.1ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 517.8ms
# Speed: 7.0ms preprocess, 517.8ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 318.6ms
# Speed: 3.3ms preprocess, 318.6ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 2 trucks, 316.4ms
# Speed: 3.3ms preprocess, 316.4ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 2 trucks, 315.0ms
# Speed: 4.1ms preprocess, 315.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 335.1ms
# Speed: 4.0ms preprocess, 335.1ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 321.3ms
# Speed: 3.1ms preprocess, 321.3ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 315.8ms
# Speed: 2.5ms preprocess, 315.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 317.1ms
# Speed: 2.5ms preprocess, 317.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 323.3ms
# Speed: 3.2ms preprocess, 323.3ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 318.4ms
# Speed: 3.1ms preprocess, 318.4ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 3 trucks, 322.0ms
# Speed: 3.1ms preprocess, 322.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 319.9ms
# Speed: 2.4ms preprocess, 319.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 309.5ms
# Speed: 3.6ms preprocess, 309.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 329.1ms
# Speed: 3.8ms preprocess, 329.1ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 310.0ms
# Speed: 3.9ms preprocess, 310.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 313.4ms
# Speed: 3.3ms preprocess, 313.4ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 326.0ms
# Speed: 3.3ms preprocess, 326.0ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 316.1ms
# Speed: 3.3ms preprocess, 316.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 3 trucks, 306.8ms
# Speed: 3.1ms preprocess, 306.8ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 330.0ms
# Speed: 3.7ms preprocess, 330.0ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 3 trucks, 321.7ms
# Speed: 3.3ms preprocess, 321.7ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 3 trucks, 311.0ms
# Speed: 3.1ms preprocess, 311.0ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 3 trucks, 327.9ms
# Speed: 5.2ms preprocess, 327.9ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 365.4ms
# Speed: 3.8ms preprocess, 365.4ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 504.2ms
# Speed: 3.7ms preprocess, 504.2ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 488.2ms
# Speed: 3.5ms preprocess, 488.2ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 489.3ms
# Speed: 3.7ms preprocess, 489.3ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 525.8ms
# Speed: 3.5ms preprocess, 525.8ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 548.9ms
# Speed: 3.1ms preprocess, 548.9ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 509.1ms
# Speed: 3.2ms preprocess, 509.1ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 3 trucks, 548.6ms
# Speed: 4.1ms preprocess, 548.6ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 511.0ms
# Speed: 3.4ms preprocess, 511.0ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 355.9ms
# Speed: 9.2ms preprocess, 355.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 338.6ms
# Speed: 3.1ms preprocess, 338.6ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 342.6ms
# Speed: 4.1ms preprocess, 342.6ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 314.4ms
# Speed: 4.7ms preprocess, 314.4ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 343.8ms
# Speed: 3.2ms preprocess, 343.8ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 341.1ms
# Speed: 3.5ms preprocess, 341.1ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 318.9ms
# Speed: 3.3ms preprocess, 318.9ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 330.7ms
# Speed: 3.3ms preprocess, 330.7ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 1 bench, 339.2ms
# Speed: 3.1ms preprocess, 339.2ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 1 bench, 316.1ms
# Speed: 3.0ms preprocess, 316.1ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 1 bench, 317.1ms
# Speed: 4.8ms preprocess, 317.1ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 2 trucks, 1 bench, 355.8ms
# Speed: 4.3ms preprocess, 355.8ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 cars, 1 truck, 1 bench, 320.1ms
# Speed: 3.8ms preprocess, 320.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 1 bench, 327.3ms
# Speed: 3.8ms preprocess, 327.3ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 1 bench, 311.8ms
# Speed: 3.2ms preprocess, 311.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 1 bench, 310.0ms
# Speed: 4.0ms preprocess, 310.0ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 truck, 1 bench, 310.7ms
# Speed: 3.3ms preprocess, 310.7ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 truck, 1 bench, 312.2ms
# Speed: 3.4ms preprocess, 312.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 truck, 1 bench, 315.2ms
# Speed: 3.6ms preprocess, 315.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 2 trucks, 324.1ms
# Speed: 3.2ms preprocess, 324.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 2 trucks, 311.9ms
# Speed: 3.9ms preprocess, 311.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 2 trucks, 305.8ms
# Speed: 3.3ms preprocess, 305.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 2 trucks, 328.1ms
# Speed: 3.7ms preprocess, 328.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 2 trucks, 306.8ms
# Speed: 3.4ms preprocess, 306.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 truck, 324.6ms
# Speed: 4.4ms preprocess, 324.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 324.0ms
# Speed: 3.3ms preprocess, 324.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 304.6ms
# Speed: 3.1ms preprocess, 304.6ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 2 trucks, 1 bench, 443.3ms
# Speed: 4.7ms preprocess, 443.3ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 1 bench, 564.0ms
# Speed: 5.0ms preprocess, 564.0ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 1 truck, 514.3ms
# Speed: 3.4ms preprocess, 514.3ms inference, 6.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 12 cars, 1 truck, 515.1ms
# Speed: 3.3ms preprocess, 515.1ms inference, 4.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 12 cars, 2 trucks, 480.7ms
# Speed: 3.1ms preprocess, 480.7ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 2 trucks, 506.5ms
# Speed: 4.5ms preprocess, 506.5ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 2 trucks, 544.7ms
# Speed: 3.3ms preprocess, 544.7ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 2 trucks, 521.1ms
# Speed: 3.2ms preprocess, 521.1ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 2 trucks, 502.5ms
# Speed: 3.1ms preprocess, 502.5ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 3 trucks, 325.6ms
# Speed: 3.8ms preprocess, 325.6ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 truck, 309.1ms
# Speed: 3.8ms preprocess, 309.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 2 trucks, 326.9ms
# Speed: 3.3ms preprocess, 326.9ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 2 trucks, 308.4ms
# Speed: 5.3ms preprocess, 308.4ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 2 trucks, 318.1ms
# Speed: 3.1ms preprocess, 318.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 12 cars, 1 truck, 328.4ms
# Speed: 5.2ms preprocess, 328.4ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 12 cars, 1 truck, 310.9ms
# Speed: 4.5ms preprocess, 310.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 12 cars, 1 truck, 308.1ms
# Speed: 3.2ms preprocess, 308.1ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 12 cars, 2 trucks, 320.1ms
# Speed: 3.3ms preprocess, 320.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 12 cars, 2 trucks, 307.7ms
# Speed: 3.4ms preprocess, 307.7ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 2 trucks, 318.3ms
# Speed: 3.2ms preprocess, 318.3ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 10 cars, 2 trucks, 333.1ms
# Speed: 3.7ms preprocess, 333.1ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 3 trucks, 307.5ms
# Speed: 3.2ms preprocess, 307.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 2 trucks, 317.1ms
# Speed: 4.1ms preprocess, 317.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 12 cars, 2 trucks, 322.9ms
# Speed: 3.5ms preprocess, 322.9ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 12 cars, 2 trucks, 309.9ms
# Speed: 3.0ms preprocess, 309.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 2 trucks, 309.6ms
# Speed: 3.7ms preprocess, 309.6ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 3 trucks, 327.5ms
# Speed: 4.3ms preprocess, 327.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 3 trucks, 313.1ms
# Speed: 3.8ms preprocess, 313.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 10 cars, 3 trucks, 367.8ms
# Speed: 3.9ms preprocess, 367.8ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 9 cars, 3 trucks, 503.6ms
# Speed: 3.6ms preprocess, 503.6ms inference, 3.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 10 cars, 2 trucks, 481.1ms
# Speed: 7.8ms preprocess, 481.1ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 3 trucks, 319.2ms
# Speed: 3.7ms preprocess, 319.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 3 trucks, 310.8ms
# Speed: 3.8ms preprocess, 310.8ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 4 trucks, 331.6ms
# Speed: 3.4ms preprocess, 331.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 7 cars, 5 trucks, 313.8ms
# Speed: 3.3ms preprocess, 313.8ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 7 cars, 5 trucks, 324.8ms
# Speed: 4.1ms preprocess, 324.8ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 4 trucks, 488.9ms
# Speed: 3.2ms preprocess, 488.9ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 3 trucks, 490.9ms
# Speed: 3.3ms preprocess, 490.9ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 5 trucks, 481.8ms
# Speed: 3.1ms preprocess, 481.8ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 3 trucks, 481.9ms
# Speed: 3.2ms preprocess, 481.9ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 3 trucks, 498.2ms
# Speed: 4.1ms preprocess, 498.2ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 4 trucks, 519.4ms
# Speed: 3.1ms preprocess, 519.4ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 4 trucks, 502.0ms
# Speed: 3.1ms preprocess, 502.0ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 4 trucks, 406.4ms
# Speed: 3.0ms preprocess, 406.4ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 4 trucks, 382.9ms
# Speed: 3.5ms preprocess, 382.9ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 4 trucks, 416.3ms
# Speed: 4.5ms preprocess, 416.3ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 3 trucks, 545.6ms
# Speed: 4.3ms preprocess, 545.6ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 3 trucks, 366.8ms
# Speed: 4.3ms preprocess, 366.8ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 3 trucks, 323.0ms
# Speed: 4.7ms preprocess, 323.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 8 cars, 3 trucks, 331.8ms
# Speed: 2.7ms preprocess, 331.8ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 8 cars, 3 trucks, 363.1ms
# Speed: 3.8ms preprocess, 363.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 7 cars, 3 trucks, 425.8ms
# Speed: 4.4ms preprocess, 425.8ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 8 cars, 3 trucks, 379.3ms
# Speed: 9.2ms preprocess, 379.3ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 8 cars, 4 trucks, 718.0ms
# Speed: 3.4ms preprocess, 718.0ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 7 cars, 3 trucks, 864.7ms
# Speed: 4.9ms preprocess, 864.7ms inference, 4.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 7 cars, 3 trucks, 679.4ms
# Speed: 7.9ms preprocess, 679.4ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 7 cars, 3 trucks, 555.4ms
# Speed: 5.7ms preprocess, 555.4ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 7 cars, 3 trucks, 330.6ms
# Speed: 10.7ms preprocess, 330.6ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 8 cars, 3 trucks, 331.1ms
# Speed: 4.5ms preprocess, 331.1ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 8 cars, 4 trucks, 316.8ms
# Speed: 4.0ms preprocess, 316.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 8 cars, 5 trucks, 316.4ms
# Speed: 3.9ms preprocess, 316.4ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 8 cars, 4 trucks, 329.1ms
# Speed: 4.1ms preprocess, 329.1ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 8 cars, 5 trucks, 316.7ms
# Speed: 3.3ms preprocess, 316.7ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 8 cars, 5 trucks, 356.8ms
# Speed: 3.4ms preprocess, 356.8ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 9 cars, 4 trucks, 496.3ms
# Speed: 3.4ms preprocess, 496.3ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 10 cars, 5 trucks, 484.2ms
# Speed: 3.5ms preprocess, 484.2ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 10 cars, 5 trucks, 490.0ms
# Speed: 3.5ms preprocess, 490.0ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 10 cars, 4 trucks, 486.6ms
# Speed: 3.3ms preprocess, 486.6ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 9 cars, 4 trucks, 510.6ms
# Speed: 6.3ms preprocess, 510.6ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 10 cars, 3 trucks, 519.0ms
# Speed: 4.6ms preprocess, 519.0ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 9 cars, 3 trucks, 541.3ms
# Speed: 4.7ms preprocess, 541.3ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 9 cars, 3 trucks, 406.3ms
# Speed: 4.1ms preprocess, 406.3ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 9 cars, 3 trucks, 309.9ms
# Speed: 3.3ms preprocess, 309.9ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 3 trucks, 323.9ms
# Speed: 2.8ms preprocess, 323.9ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 3 trucks, 326.3ms
# Speed: 4.0ms preprocess, 326.3ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 3 trucks, 314.2ms
# Speed: 3.7ms preprocess, 314.2ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 3 trucks, 317.8ms
# Speed: 3.2ms preprocess, 317.8ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 3 trucks, 317.3ms
# Speed: 3.3ms preprocess, 317.3ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 3 trucks, 395.8ms
# Speed: 5.1ms preprocess, 395.8ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 9 cars, 3 trucks, 522.5ms
# Speed: 3.2ms preprocess, 522.5ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 9 cars, 3 trucks, 395.2ms
# Speed: 3.1ms preprocess, 395.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 10 cars, 3 trucks, 325.4ms
# Speed: 4.9ms preprocess, 325.4ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 3 trucks, 317.8ms
# Speed: 3.6ms preprocess, 317.8ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 3 trucks, 312.6ms
# Speed: 4.0ms preprocess, 312.6ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 12 cars, 3 trucks, 318.9ms
# Speed: 5.2ms preprocess, 318.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 3 trucks, 317.3ms
# Speed: 3.1ms preprocess, 317.3ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 12 cars, 3 trucks, 322.3ms
# Speed: 3.1ms preprocess, 322.3ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 12 cars, 3 trucks, 317.3ms
# Speed: 3.1ms preprocess, 317.3ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 13 cars, 3 trucks, 321.5ms
# Speed: 4.6ms preprocess, 321.5ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 12 cars, 3 trucks, 318.7ms
# Speed: 3.1ms preprocess, 318.7ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 12 cars, 4 trucks, 314.7ms
# Speed: 3.1ms preprocess, 314.7ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 4 trucks, 320.3ms
# Speed: 3.0ms preprocess, 320.3ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 12 cars, 4 trucks, 327.9ms
# Speed: 3.3ms preprocess, 327.9ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 6 trucks, 307.2ms
# Speed: 2.5ms preprocess, 307.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 9 cars, 5 trucks, 315.9ms
# Speed: 3.1ms preprocess, 315.9ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 5 trucks, 318.7ms
# Speed: 4.0ms preprocess, 318.7ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 4 trucks, 312.2ms
# Speed: 4.0ms preprocess, 312.2ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 3 trucks, 308.7ms
# Speed: 2.3ms preprocess, 308.7ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 4 trucks, 404.0ms
# Speed: 4.6ms preprocess, 404.0ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 4 trucks, 473.5ms
# Speed: 3.6ms preprocess, 473.5ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 4 trucks, 501.5ms
# Speed: 3.3ms preprocess, 501.5ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 6 trucks, 492.0ms
# Speed: 3.3ms preprocess, 492.0ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 6 trucks, 482.8ms
# Speed: 3.5ms preprocess, 482.8ms inference, 4.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 5 trucks, 541.3ms
# Speed: 3.9ms preprocess, 541.3ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 4 trucks, 519.9ms
# Speed: 3.2ms preprocess, 519.9ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 6 trucks, 545.3ms
# Speed: 3.3ms preprocess, 545.3ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 5 trucks, 520.9ms
# Speed: 3.1ms preprocess, 520.9ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 5 trucks, 384.8ms
# Speed: 3.1ms preprocess, 384.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 6 trucks, 305.2ms
# Speed: 4.0ms preprocess, 305.2ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 6 trucks, 324.5ms
# Speed: 3.6ms preprocess, 324.5ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 5 trucks, 325.1ms
# Speed: 3.1ms preprocess, 325.1ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 5 trucks, 315.3ms
# Speed: 3.1ms preprocess, 315.3ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 5 trucks, 338.9ms
# Speed: 3.1ms preprocess, 338.9ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 5 trucks, 307.9ms
# Speed: 3.7ms preprocess, 307.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 6 trucks, 312.9ms
# Speed: 3.1ms preprocess, 312.9ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 5 trucks, 333.2ms
# Speed: 3.6ms preprocess, 333.2ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 6 trucks, 341.0ms
# Speed: 3.2ms preprocess, 341.0ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 6 trucks, 309.2ms
# Speed: 3.9ms preprocess, 309.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 7 trucks, 335.3ms
# Speed: 3.8ms preprocess, 335.3ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 6 trucks, 309.0ms
# Speed: 4.3ms preprocess, 309.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 4 trucks, 311.6ms
# Speed: 5.3ms preprocess, 311.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 5 trucks, 331.9ms
# Speed: 3.6ms preprocess, 331.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 7 trucks, 305.1ms
# Speed: 3.9ms preprocess, 305.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 7 cars, 6 trucks, 318.5ms
# Speed: 3.3ms preprocess, 318.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 8 cars, 7 trucks, 331.0ms
# Speed: 3.7ms preprocess, 331.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 5 trucks, 302.8ms
# Speed: 3.2ms preprocess, 302.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 5 trucks, 320.4ms
# Speed: 3.1ms preprocess, 320.4ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 8 cars, 5 trucks, 320.5ms
# Speed: 3.2ms preprocess, 320.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 9 cars, 5 trucks, 308.6ms
# Speed: 3.1ms preprocess, 308.6ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 10 cars, 4 trucks, 314.7ms
# Speed: 2.9ms preprocess, 314.7ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 10 cars, 4 trucks, 318.0ms
# Speed: 3.3ms preprocess, 318.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 8 cars, 4 trucks, 319.1ms
# Speed: 3.8ms preprocess, 319.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 8 cars, 4 trucks, 307.0ms
# Speed: 3.4ms preprocess, 307.0ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 8 cars, 5 trucks, 480.0ms
# Speed: 3.3ms preprocess, 480.0ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 7 cars, 4 trucks, 478.9ms
# Speed: 5.8ms preprocess, 478.9ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 9 cars, 2 trucks, 523.2ms
# Speed: 3.3ms preprocess, 523.2ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 9 cars, 3 trucks, 597.3ms
# Speed: 3.6ms preprocess, 597.3ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 8 cars, 3 trucks, 575.5ms
# Speed: 3.5ms preprocess, 575.5ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 8 cars, 5 trucks, 517.8ms
# Speed: 3.5ms preprocess, 517.8ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 8 cars, 5 trucks, 532.4ms
# Speed: 3.6ms preprocess, 532.4ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 7 cars, 5 trucks, 508.6ms
# Speed: 3.1ms preprocess, 508.6ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 4 trucks, 329.2ms
# Speed: 5.9ms preprocess, 329.2ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 3 trucks, 337.6ms
# Speed: 4.5ms preprocess, 337.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 5 trucks, 307.2ms
# Speed: 4.4ms preprocess, 307.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 4 trucks, 315.7ms
# Speed: 4.4ms preprocess, 315.7ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 4 trucks, 319.2ms
# Speed: 5.0ms preprocess, 319.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 316.7ms
# Speed: 2.8ms preprocess, 316.7ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 315.6ms
# Speed: 4.2ms preprocess, 315.6ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 3 trucks, 318.0ms
# Speed: 4.0ms preprocess, 318.0ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 3 trucks, 319.1ms
# Speed: 3.6ms preprocess, 319.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 3 trucks, 314.3ms
# Speed: 3.8ms preprocess, 314.3ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 3 trucks, 332.2ms
# Speed: 4.4ms preprocess, 332.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 3 trucks, 317.3ms
# Speed: 4.2ms preprocess, 317.3ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 3 trucks, 310.5ms
# Speed: 3.5ms preprocess, 310.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 4 trucks, 323.3ms
# Speed: 3.9ms preprocess, 323.3ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 4 trucks, 319.2ms
# Speed: 3.9ms preprocess, 319.2ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 5 trucks, 312.7ms
# Speed: 3.5ms preprocess, 312.7ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 4 trucks, 329.3ms
# Speed: 3.2ms preprocess, 329.3ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 4 trucks, 324.1ms
# Speed: 4.3ms preprocess, 324.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 5 trucks, 307.3ms
# Speed: 3.1ms preprocess, 307.3ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 4 trucks, 330.6ms
# Speed: 3.0ms preprocess, 330.6ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 10 cars, 4 trucks, 328.7ms
# Speed: 3.3ms preprocess, 328.7ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 10 cars, 4 trucks, 303.4ms
# Speed: 3.4ms preprocess, 303.4ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 10 cars, 4 trucks, 334.7ms
# Speed: 3.2ms preprocess, 334.7ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 10 cars, 4 trucks, 376.1ms
# Speed: 3.1ms preprocess, 376.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 10 cars, 4 trucks, 517.9ms
# Speed: 2.6ms preprocess, 517.9ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 3 trucks, 438.2ms
# Speed: 6.4ms preprocess, 438.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 4 trucks, 899.8ms
# Speed: 3.3ms preprocess, 899.8ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 cars, 3 trucks, 1009.4ms
# Speed: 4.2ms preprocess, 1009.4ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 3 trucks, 949.6ms
# Speed: 4.4ms preprocess, 949.6ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 4 trucks, 511.6ms
# Speed: 3.2ms preprocess, 511.6ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 4 trucks, 529.8ms
# Speed: 3.2ms preprocess, 529.8ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 3 trucks, 475.2ms
# Speed: 3.2ms preprocess, 475.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 3 trucks, 316.8ms
# Speed: 3.5ms preprocess, 316.8ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 3 trucks, 306.5ms
# Speed: 3.3ms preprocess, 306.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 3 trucks, 331.4ms
# Speed: 2.6ms preprocess, 331.4ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 2 trucks, 306.9ms
# Speed: 4.3ms preprocess, 306.9ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 3 trucks, 314.8ms
# Speed: 3.4ms preprocess, 314.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 2 trucks, 327.4ms
# Speed: 3.5ms preprocess, 327.4ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 3 trucks, 310.5ms
# Speed: 3.2ms preprocess, 310.5ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 3 trucks, 311.2ms
# Speed: 3.6ms preprocess, 311.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 2 trucks, 330.8ms
# Speed: 3.9ms preprocess, 330.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 324.7ms
# Speed: 3.2ms preprocess, 324.7ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 321.6ms
# Speed: 3.3ms preprocess, 321.6ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 323.3ms
# Speed: 4.4ms preprocess, 323.3ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 314.1ms
# Speed: 3.0ms preprocess, 314.1ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 10 cars, 2 trucks, 319.3ms
# Speed: 3.8ms preprocess, 319.3ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 353.7ms
# Speed: 3.5ms preprocess, 353.7ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 10 cars, 2 trucks, 471.8ms
# Speed: 4.3ms preprocess, 471.8ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 3 trucks, 518.5ms
# Speed: 3.2ms preprocess, 518.5ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 310.4ms
# Speed: 3.6ms preprocess, 310.4ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 331.0ms
# Speed: 3.1ms preprocess, 331.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 304.0ms
# Speed: 3.6ms preprocess, 304.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 3 trucks, 312.2ms
# Speed: 3.5ms preprocess, 312.2ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 3 trucks, 325.7ms
# Speed: 3.2ms preprocess, 325.7ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 306.7ms
# Speed: 3.2ms preprocess, 306.7ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 10 cars, 2 trucks, 314.2ms
# Speed: 3.1ms preprocess, 314.2ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 324.4ms
# Speed: 4.5ms preprocess, 324.4ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 9 cars, 2 trucks, 324.8ms
# Speed: 3.7ms preprocess, 324.8ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 348.4ms
# Speed: 4.2ms preprocess, 348.4ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 9 cars, 2 trucks, 490.1ms
# Speed: 6.6ms preprocess, 490.1ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 9 cars, 2 trucks, 483.4ms
# Speed: 3.1ms preprocess, 483.4ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 9 cars, 2 trucks, 474.7ms
# Speed: 3.9ms preprocess, 474.7ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 8 cars, 2 trucks, 498.9ms
# Speed: 3.5ms preprocess, 498.9ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 505.0ms
# Speed: 3.2ms preprocess, 505.0ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 8 cars, 2 trucks, 532.6ms
# Speed: 3.4ms preprocess, 532.6ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 509.8ms
# Speed: 4.5ms preprocess, 509.8ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 2 trucks, 324.4ms
# Speed: 5.3ms preprocess, 324.4ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 7 cars, 2 trucks, 327.3ms
# Speed: 3.2ms preprocess, 327.3ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 9 cars, 2 trucks, 320.9ms
# Speed: 3.6ms preprocess, 320.9ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 9 cars, 2 trucks, 324.8ms
# Speed: 5.2ms preprocess, 324.8ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 10 cars, 2 trucks, 326.4ms
# Speed: 4.0ms preprocess, 326.4ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 3 trucks, 328.5ms
# Speed: 3.5ms preprocess, 328.5ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 3 trucks, 338.5ms
# Speed: 4.0ms preprocess, 338.5ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 10 cars, 3 trucks, 411.8ms
# Speed: 3.3ms preprocess, 411.8ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 9 cars, 3 trucks, 551.7ms
# Speed: 3.5ms preprocess, 551.7ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 9 cars, 3 trucks, 412.4ms
# Speed: 3.3ms preprocess, 412.4ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 3 trucks, 321.6ms
# Speed: 3.8ms preprocess, 321.6ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 4 trucks, 327.5ms
# Speed: 3.6ms preprocess, 327.5ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 3 trucks, 309.3ms
# Speed: 3.3ms preprocess, 309.3ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 3 trucks, 320.6ms
# Speed: 4.0ms preprocess, 320.6ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 2 trucks, 319.8ms
# Speed: 4.7ms preprocess, 319.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 2 trucks, 315.5ms
# Speed: 3.2ms preprocess, 315.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 2 trucks, 313.2ms
# Speed: 4.2ms preprocess, 313.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 2 trucks, 320.9ms
# Speed: 3.5ms preprocess, 320.9ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 2 trucks, 350.9ms
# Speed: 3.8ms preprocess, 350.9ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 2 trucks, 696.2ms
# Speed: 3.3ms preprocess, 696.2ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 2 trucks, 544.6ms
# Speed: 3.3ms preprocess, 544.6ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 2 trucks, 706.6ms
# Speed: 3.7ms preprocess, 706.6ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 cars, 2 trucks, 991.7ms
# Speed: 3.6ms preprocess, 991.7ms inference, 16.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 2 trucks, 934.1ms
# Speed: 7.2ms preprocess, 934.1ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 2 trucks, 591.4ms
# Speed: 3.3ms preprocess, 591.4ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 2 trucks, 1 bench, 1411.0ms
# Speed: 8.3ms preprocess, 1411.0ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 2 trucks, 1303.1ms
# Speed: 4.5ms preprocess, 1303.1ms inference, 5.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 2 trucks, 653.3ms
# Speed: 5.0ms preprocess, 653.3ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 2 trucks, 322.4ms
# Speed: 4.5ms preprocess, 322.4ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 cars, 2 trucks, 310.4ms
# Speed: 5.0ms preprocess, 310.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 cars, 2 trucks, 313.9ms
# Speed: 4.0ms preprocess, 313.9ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 cars, 2 trucks, 320.9ms
# Speed: 3.9ms preprocess, 320.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 cars, 3 trucks, 310.7ms
# Speed: 3.8ms preprocess, 310.7ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 cars, 2 trucks, 300.7ms
# Speed: 4.1ms preprocess, 300.7ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 2 trucks, 326.8ms
# Speed: 5.3ms preprocess, 326.8ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 2 trucks, 307.7ms
# Speed: 4.5ms preprocess, 307.7ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 2 trucks, 318.1ms
# Speed: 5.4ms preprocess, 318.1ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 2 trucks, 332.4ms
# Speed: 3.5ms preprocess, 332.4ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 2 trucks, 312.7ms
# Speed: 4.5ms preprocess, 312.7ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 2 trucks, 319.6ms
# Speed: 4.6ms preprocess, 319.6ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 2 trucks, 325.8ms
# Speed: 3.2ms preprocess, 325.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 2 trucks, 321.1ms
# Speed: 3.2ms preprocess, 321.1ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 316.1ms
# Speed: 3.3ms preprocess, 316.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 3 trucks, 319.0ms
# Speed: 4.7ms preprocess, 319.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 2 trucks, 320.8ms
# Speed: 3.0ms preprocess, 320.8ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 3 trucks, 310.2ms
# Speed: 3.5ms preprocess, 310.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 3 trucks, 323.8ms
# Speed: 3.7ms preprocess, 323.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 3 trucks, 306.3ms
# Speed: 3.9ms preprocess, 306.3ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 2 trucks, 314.7ms
# Speed: 3.4ms preprocess, 314.7ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 2 trucks, 323.3ms
# Speed: 3.2ms preprocess, 323.3ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 2 trucks, 312.5ms
# Speed: 3.9ms preprocess, 312.5ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 2 trucks, 311.2ms
# Speed: 4.0ms preprocess, 311.2ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 2 trucks, 315.2ms
# Speed: 5.9ms preprocess, 315.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 2 trucks, 313.9ms
# Speed: 3.2ms preprocess, 313.9ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 2 trucks, 316.7ms
# Speed: 3.2ms preprocess, 316.7ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 3 trucks, 522.9ms
# Speed: 3.2ms preprocess, 522.9ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 3 trucks, 535.0ms
# Speed: 3.2ms preprocess, 535.0ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 4 trucks, 521.2ms
# Speed: 6.6ms preprocess, 521.2ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 3 trucks, 517.6ms
# Speed: 3.3ms preprocess, 517.6ms inference, 4.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 4 trucks, 524.4ms
# Speed: 3.6ms preprocess, 524.4ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 3 trucks, 500.0ms
# Speed: 4.0ms preprocess, 500.0ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 534.2ms
# Speed: 3.6ms preprocess, 534.2ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 2 trucks, 540.6ms
# Speed: 3.6ms preprocess, 540.6ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 537.0ms
# Speed: 3.7ms preprocess, 537.0ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 3 trucks, 332.0ms
# Speed: 3.7ms preprocess, 332.0ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 4 trucks, 327.0ms
# Speed: 4.9ms preprocess, 327.0ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 5 trucks, 310.3ms
# Speed: 4.8ms preprocess, 310.3ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 4 trucks, 342.0ms
# Speed: 4.0ms preprocess, 342.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 4 trucks, 344.3ms
# Speed: 3.9ms preprocess, 344.3ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 4 trucks, 314.6ms
# ...
#
# 0: 320x640 8 cars, 3 trucks, 315.9ms
# Speed: 3.1ms preprocess, 315.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 3 trucks, 317.3ms
# Speed: 3.5ms preprocess, 317.3ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 327.8ms
# Speed: 3.2ms preprocess, 327.8ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 321.0ms
# Speed: 3.4ms preprocess, 321.0ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 495.4ms
# Speed: 8.0ms preprocess, 495.4ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 494.6ms
# Speed: 3.4ms preprocess, 494.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 2 trucks, 480.1ms
# Speed: 3.3ms preprocess, 480.1ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 2 trucks, 509.4ms
# Speed: 3.6ms preprocess, 509.4ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 500.0ms
# Speed: 5.5ms preprocess, 500.0ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 534.3ms
# Speed: 3.2ms preprocess, 534.3ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 563.5ms
# Speed: 3.3ms preprocess, 563.5ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 581.1ms
# Speed: 5.3ms preprocess, 581.1ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 621.0ms
# Speed: 5.0ms preprocess, 621.0ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 410.3ms
# Speed: 3.1ms preprocess, 410.3ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 331.8ms
# Speed: 4.3ms preprocess, 331.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 321.9ms
# Speed: 3.3ms preprocess, 321.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 315.5ms
# Speed: 3.2ms preprocess, 315.5ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 331.6ms
# Speed: 5.1ms preprocess, 331.6ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 303.9ms
# Speed: 3.3ms preprocess, 303.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 327.8ms
# Speed: 3.1ms preprocess, 327.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 322.3ms
# Speed: 3.7ms preprocess, 322.3ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 310.4ms
# Speed: 3.8ms preprocess, 310.4ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 312.3ms
# Speed: 4.9ms preprocess, 312.3ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 323.3ms
# Speed: 3.2ms preprocess, 323.3ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 317.0ms
# Speed: 3.4ms preprocess, 317.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 320.5ms
# Speed: 7.4ms preprocess, 320.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 8 cars, 1 truck, 325.5ms
# Speed: 3.3ms preprocess, 325.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 321.9ms
# Speed: 3.2ms preprocess, 321.9ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 321.5ms
# Speed: 3.0ms preprocess, 321.5ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 320.9ms
# Speed: 6.2ms preprocess, 320.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 308.5ms
# Speed: 4.1ms preprocess, 308.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 317.4ms
# Speed: 3.1ms preprocess, 317.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 317.3ms
# Speed: 3.3ms preprocess, 317.3ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 313.9ms
# Speed: 5.7ms preprocess, 313.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 327.9ms
# Speed: 4.1ms preprocess, 327.9ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 3 trucks, 309.6ms
# Speed: 3.3ms preprocess, 309.6ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 4 trucks, 318.7ms
# Speed: 5.1ms preprocess, 318.7ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 3 trucks, 324.6ms
# Speed: 3.2ms preprocess, 324.6ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 313.4ms
# Speed: 3.8ms preprocess, 313.4ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 3 trucks, 321.7ms
# Speed: 3.2ms preprocess, 321.7ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 3 trucks, 356.5ms
# Speed: 5.1ms preprocess, 356.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 4 trucks, 526.9ms
# Speed: 7.9ms preprocess, 526.9ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 3 trucks, 567.3ms
# Speed: 3.5ms preprocess, 567.3ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 4 trucks, 498.7ms
# Speed: 3.3ms preprocess, 498.7ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 4 trucks, 480.2ms
# Speed: 3.3ms preprocess, 480.2ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 4 trucks, 483.1ms
# Speed: 3.4ms preprocess, 483.1ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 3 trucks, 493.1ms
# Speed: 3.5ms preprocess, 493.1ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 3 trucks, 524.3ms
# Speed: 3.3ms preprocess, 524.3ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 4 trucks, 529.5ms
# Speed: 4.3ms preprocess, 529.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 3 trucks, 502.2ms
# Speed: 3.3ms preprocess, 502.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 2 trucks, 324.1ms
# Speed: 5.4ms preprocess, 324.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 2 trucks, 322.8ms
# Speed: 4.3ms preprocess, 322.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 318.1ms
# Speed: 3.7ms preprocess, 318.1ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 3 trucks, 311.8ms
# Speed: 4.8ms preprocess, 311.8ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 3 trucks, 328.8ms
# Speed: 3.3ms preprocess, 328.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 3 trucks, 321.9ms
# Speed: 3.6ms preprocess, 321.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 4 trucks, 314.9ms
# Speed: 3.2ms preprocess, 314.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 4 trucks, 306.9ms
# Speed: 3.3ms preprocess, 306.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 3 trucks, 318.7ms
# Speed: 3.9ms preprocess, 318.7ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 3 trucks, 312.8ms
# Speed: 3.3ms preprocess, 312.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 4 trucks, 314.8ms
# Speed: 3.1ms preprocess, 314.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 3 trucks, 319.4ms
# Speed: 4.9ms preprocess, 319.4ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 316.9ms
# Speed: 3.7ms preprocess, 316.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 316.2ms
# Speed: 4.7ms preprocess, 316.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 321.1ms
# Speed: 3.1ms preprocess, 321.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 319.4ms
# Speed: 3.5ms preprocess, 319.4ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 310.4ms
# Speed: 4.8ms preprocess, 310.4ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 329.1ms
# Speed: 3.9ms preprocess, 329.1ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 345.7ms
# Speed: 3.2ms preprocess, 345.7ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 479.7ms
# Speed: 10.0ms preprocess, 479.7ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 478.5ms
# Speed: 3.4ms preprocess, 478.5ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 317.9ms
# Speed: 3.9ms preprocess, 317.9ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 320.9ms
# Speed: 3.3ms preprocess, 320.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 317.3ms
# Speed: 3.2ms preprocess, 317.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 312.3ms
# Speed: 3.1ms preprocess, 312.3ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 326.5ms
# Speed: 3.6ms preprocess, 326.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 367.2ms
# Speed: 4.9ms preprocess, 367.2ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 494.5ms
# Speed: 3.9ms preprocess, 494.5ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 474.0ms
# Speed: 3.4ms preprocess, 474.0ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 494.9ms
# Speed: 3.2ms preprocess, 494.9ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 491.2ms
# Speed: 3.2ms preprocess, 491.2ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 503.9ms
# Speed: 3.1ms preprocess, 503.9ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 514.8ms
# Speed: 3.3ms preprocess, 514.8ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 546.2ms
# Speed: 5.8ms preprocess, 546.2ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 406.8ms
# Speed: 8.8ms preprocess, 406.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 330.7ms
# Speed: 3.2ms preprocess, 330.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 10 cars, 1 truck, 310.7ms
# Speed: 3.9ms preprocess, 310.7ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 315.0ms
# Speed: 3.2ms preprocess, 315.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 325.4ms
# Speed: 3.8ms preprocess, 325.4ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 322.9ms
# Speed: 4.0ms preprocess, 322.9ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 311.0ms
# Speed: 6.3ms preprocess, 311.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 321.6ms
# Speed: 4.9ms preprocess, 321.6ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 311.1ms
# Speed: 5.1ms preprocess, 311.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 314.4ms
# Speed: 3.3ms preprocess, 314.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 345.7ms
# Speed: 3.2ms preprocess, 345.7ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 475.0ms
# Speed: 3.4ms preprocess, 475.0ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 543.5ms
# Speed: 3.4ms preprocess, 543.5ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 310.8ms
# Speed: 4.3ms preprocess, 310.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 1 truck, 323.4ms
# Speed: 4.5ms preprocess, 323.4ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 312.5ms
# Speed: 3.2ms preprocess, 312.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 313.8ms
# Speed: 3.1ms preprocess, 313.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 326.1ms
# Speed: 4.7ms preprocess, 326.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 315.3ms
# Speed: 3.6ms preprocess, 315.3ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 308.7ms
# Speed: 3.2ms preprocess, 308.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 324.4ms
# Speed: 4.2ms preprocess, 324.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 308.0ms
# Speed: 7.2ms preprocess, 308.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 311.9ms
# Speed: 4.0ms preprocess, 311.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 326.2ms
# Speed: 5.4ms preprocess, 326.2ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 308.1ms
# Speed: 3.4ms preprocess, 308.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 316.7ms
# Speed: 3.9ms preprocess, 316.7ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 2 trucks, 314.1ms
# Speed: 3.3ms preprocess, 314.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 2 trucks, 429.8ms
# Speed: 3.4ms preprocess, 429.8ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 1 truck, 484.7ms
# Speed: 3.1ms preprocess, 484.7ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 1 truck, 473.7ms
# Speed: 3.2ms preprocess, 473.7ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 10 cars, 1 truck, 493.6ms
# Speed: 3.3ms preprocess, 493.6ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 10 cars, 1 truck, 495.7ms
# Speed: 4.6ms preprocess, 495.7ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 10 cars, 2 trucks, 528.8ms
# Speed: 4.1ms preprocess, 528.8ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)

# %%
# Load the video without sound
video = VideoFileClip("output_no_audio.avi")

# Load the beep sound
beep_clip = AudioFileClip("beep.wav")

# Create a list of beep sound clips at specific timestamps
beep_clips = []
for t in beep_timestamps:
    beep_clips.append(beep_clip.set_start(t).set_duration(beep_clip.duration))

# Combine all beep sounds into a single audio track
final_audio = CompositeAudioClip(beep_clips)

# Add the final audio to the video
final_video = video.set_audio(final_audio)

# Save the final video with beeps
final_video.write_videofile("output_with_beep.avi", codec="libx264", audio_codec="aac")
# Out:
# Moviepy - Building video output_with_beep.avi.
# MoviePy - Writing audio in output_with_beepTEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video output_with_beep.avi
# Moviepy - Done !
# Moviepy - video ready output_with_beep.avi

# %%
for k,v in tickets.items():
  time, dir, speed = v
  print(f'ID: {k} in Time {time}, Moving {dir} caught driving {speed} Km\h')
# Out:
# ID: 5 in Time 1724259373.0873482, Moving South caught driving 40.343608669068416 Km\h
# ID: 35 in Time 1724259410.6889396, Moving South caught driving 50.38727891507417 Km\h
# ID: 118 in Time 1724259528.7802558, Moving South caught driving 50.07264889269085 Km\h
# ID: 131 in Time 1724259542.6820042, Moving South caught driving 52.080570858040964 Km\h
# ID: 144 in Time 1724259565.3557897, Moving South caught driving 41.8585229911339 Km\h
# ID: 159 in Time 1724259577.3201833, Moving South caught driving 41.61353707782824 Km\h
# ID: 162 in Time 1724259586.9475954, Moving South caught driving 48.61816244754215 Km\h
# ID: 190 in Time 1724259593.0797536, Moving North caught driving 48.61816244754215 Km\h
# ID: 160 in Time 1724259598.1259177, Moving South caught driving 52.766232729662754 Km\h
# ID: 180 in Time 1724259617.859967, Moving South caught driving 43.4883552141807 Km\h
# ID: 234 in Time 1724259645.8537176, Moving South caught driving 46.05291046602684 Km\h
# ID: 262 in Time 1724259680.5877504, Moving North caught driving 31.115422630415285 Km\h
# ID: 285 in Time 1724259729.7909634, Moving South caught driving 44.24567073847911 Km\h
# ID: 290 in Time 1724259734.7363064, Moving South caught driving 50.55886797917641 Km\h
# ID: 277 in Time 1724259745.9478626, Moving South caught driving 55.10505345588134 Km\h
# ID: 311 in Time 1724259778.6353905, Moving South caught driving 49.93913472425646 Km\h
